# %%
import pandas as pd
df = pd.read_csv("C:/D/Telo🌙/python/modulo3/STREAMLIT/Data/Sevilla_airbnb.csv")

# %%
df.head()

# %%
df.isnull().sum()

# %%
#import pycaret

# %%
from pycaret.regression import *

# %%
df.columns
# Out:
# Index(['name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews_x', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365',
#        'number_of_reviews_ltm', 'license', 'host_location',
#        'host_is_superhost', 'host_listings_count', 'host_total_listings_count',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed',
#        'property_type', 'accommodates', 'number_of_reviews_y',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_location',
#        'review_scores_value', 'review_scores_checkin',
#        'review_scores_communication', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'scrape_id',
#        'listing_id'],
#       dtype='object')

# %%
df_pred = df.copy()
df_pred_new = df_pred[["neighbourhood","accommodates", "property_type", "room_type", "price", "minimum_nights", "host_is_superhost" ]]

# %%
setup = setup(df_pred_new, target = "price")
# Out:
# <style type="text/css">
# #T_2e4ca_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_2e4ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e4ca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_2e4ca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e4ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e4ca_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_2e4ca_row0_col1" class="data row0 col1" >3030</td>
#     </tr>
#     <tr>
#       <th id="T_2e4ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2e4ca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_2e4ca_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_2e4ca_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_c9d62 th {
#   text-align: left;
# }
# ...

# %%
lightgbm = create_model("lightgbm")
# Out:
# <style type="text/css">
# #T_3ab15_row10_col0, #T_3ab15_row10_col1, #T_3ab15_row10_col2, #T_3ab15_row10_col3, #T_3ab15_row10_col4, #T_3ab15_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_3ab15">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ab15_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3ab15_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3ab15_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3ab15_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3ab15_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_3ab15_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_lightgbm = tune_model(lightgbm)
# Out:
# <style type="text/css">
# #T_ad81e_row10_col0, #T_ad81e_row10_col1, #T_ad81e_row10_col2, #T_ad81e_row10_col3, #T_ad81e_row10_col4, #T_ad81e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ad81e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad81e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ad81e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ad81e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ad81e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ad81e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ad81e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tuned_lightgbm)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
final_ridge_best = finalize_model(tuned_lightgbm)

# %%
save_model(tuned_lightgbm, "ml_airbnb_sevilla")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['accommodates', 'minimum_nights'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['neighbourhood', 'property_type',
#                                               'room_type', 'host_is_superhost'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   Tra...
#                   TransformerWrapper(include=['neighbourhood', 'property_type'],
#                                      transformer=TargetEncoder(cols=['neighbourhood',
#                                                                      'property_type'],
# ...

# %%
valores_unicos = df['neighbourhood'].unique()
print(valores_unicos)
# Out:
# ['San Vicente' 'San Lorenzo' 'Feria' 'Arenal' 'Santa Cruz'
#  'León XIII, Los Naranjos' 'Las Avenidas' 'Museo' 'Alfalfa' 'San Bernardo'
#  'El Cerro' 'Encarnación, Regina' 'an Roque' 'Triana Casco Antiguo'
#  'Macarena 3 Huertas, Macarena 5' 'Triana Este' 'San Bartolomé'
#  'Triana Oeste' 'San Gil' 'El Porvenir' 'Santa Catalina' 'San Julián'
#  'Pino Flores' 'Sector Sur, La Palmera, Reina Mercedes'
#  'El Torrejón, El Cerezo' 'Doctor Barraquer, G. Renfe, Policlínico'
#  'Santa María de Ordas, San Nicolas' 'Huerta de la Salud' 'Santa Clara'
#  'San José Obrero' 'La Florida' 'Los Remedios'
#  'Palacio Congresos, Urbadiez, Entrepuentes, Jardines del Eden'
#  'Begoña, Santa Catalina' 'Valdezorras' 'La Calzada' 'San Pablo A y B'
#  'La Bachillera' 'Pedro Salvador, Las Palmeritas' 'El Tardón, El Carmen'
#  'El Plantinar' 'Cruz Roja, Capuchinos' 'Los Pajaros'
#  'Cisneo Alto, Santa María de Graccia' 'Arbol Gordo' 'Bellavista'
# ...

# %%
valores_unicos = df['room_type'].unique()
print(valores_unicos)
# Out:
# ['Entire home/apt' 'Private room' 'Hotel room' 'Shared room']

# %%
valores_unicos = df['property_type'].unique()
print(valores_unicos)
# Out:
# ['Entire rental unit' 'Entire loft' 'Entire condo' 'Entire home'
#  'Private room in rental unit' 'Private room in tiny home'
#  'Private room in townhouse' 'Entire serviced apartment'
#  'Room in serviced apartment' 'Entire chalet' 'Entire villa'
#  'Entire townhouse' 'Entire vacation home' 'Private room in home'
#  'Private room in bed and breakfast' 'Private room in serviced apartment'
#  'Room in hotel' 'Private room in hostel' 'Private room in condo'
#  'Entire cottage' 'Entire guesthouse' 'Entire guest suite'
#  'Private room in villa' 'Private room in loft' 'Room in aparthotel'
#  'Private room' 'Shared room in rental unit' 'Private room in guesthouse'
#  'Private room in casa particular' 'Entire place'
#  'Private room in earthen home' 'Casa particular' 'Shared room in home'
#  'Private room in guest suite' 'Room in bed and breakfast'
#  'Room in boutique hotel' 'Tiny home' 'Shared room in hostel'
#  'Private room in dome' 'Shared room in bed and breakfast'
# ...

# %%
super=df['host_is_superhost'].unique()
super
# Out:
# array(['f', 't'], dtype=object)
